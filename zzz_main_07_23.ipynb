# %%
from models import WeatherService
from models import Order
from models import DriverManager
from models import DriverRecord

import pandas as pd
import numpy as np
import os
import joblib
import random
import datetime

import gymnasium as gym
from gymnasium import spaces

from imblearn.ensemble import BalancedRandomForestClassifier

# %%
class DeliveryEnv(gym.Env):

    def __init__(
        self,
        order_data: pd.DataFrame,
        driver_data: pd.DataFrame,
        order_driver_data: pd.DataFrame,
        schedule_data: pd.DataFrame,
        acceptance_model: BalancedRandomForestClassifier,
        weather_service: WeatherService,
    ):
        super(DeliveryEnv, self).__init__()

        self.order_data = order_data
        self.driver_data = driver_data
        self.order_driver_data = order_driver_data
        self.schedule_data = schedule_data
        self.acceptance_model = acceptance_model
        self.weather_service = weather_service
        self.driver_record = DriverRecord()

        self.driver_manager = DriverManager(
            order_driver_data=self.order_driver_data,
            driver_data=self.driver_data,
            schedule_data=self.schedule_data,
            acceptance_model=self.acceptance_model,
            driver_record=self.driver_record,
        )

        self.order_data_specific_day_concatenated = (
            self._get_order_data_specific_day_concatenated()
        )
        self.order_ids = (
            self.order_data_specific_day_concatenated["order_id"].unique().tolist()
        )
        # important info to judge if need to update driver_manager.update_driver_set
        # when change to a new day
        self.current_order_index: int = 0
        # self.current_order_date = None
        self.previous_order_date = None
        self.order_length = len(self.order_ids)
        # Define action space (continuous commission rate between 0 and 1)
        self.action_space = spaces.Box(low=0.0, high=1.0, shape=(1,), dtype=np.float32)

        # Define state space (order + specific driver attributes)
        self.observation_space = spaces.Dict(
            {
                "customer_price": spaces.Box(
                    low=0.0, high=1.0, shape=(1,), dtype=np.float32
                ),
                "pickup_area": spaces.Discrete(501),
                "dropoff_area": spaces.Discrete(501),
                "hour_of_day": spaces.Discrete(24),
                "day_of_week": spaces.Discrete(7),
                "weather": spaces.Discrete(4),
                "driver_area": spaces.Discrete(501),
                "working_status": spaces.Discrete(2),
            }
        )

        self.state = None
        self.steps = 0

    def reset(self, seed=None):
        super().reset(seed=seed)
        self.driver_record = DriverRecord()
        self.driver_manager = DriverManager(
            order_driver_data=self.order_driver_data,
            driver_data=self.driver_data,
            schedule_data=self.schedule_data,
            acceptance_model=self.acceptance_model,
            driver_record=self.driver_record,
        )
        self.order_data_specific_day_concatenated = (
            self._get_order_data_specific_day_concatenated()
        )
        self.order_ids = (
            self.order_data_specific_day_concatenated["order_id"].unique().tolist()
        )
        # important info to judge if need to update driver_manager.update_driver_set
        # when change to a new day
        self.current_order_index: int = 0
        # self.current_order_date = None
        self.previous_order_date = None
        self.order_length = len(self.order_ids)
        self.state = None
        return self.state, {}

    def step(self, action: float):

        current_order_id = self.order_ids[self.current_order_index]
        order_data_specific_day_concatenated: pd.DataFrame = (
            self.order_data_specific_day_concatenated
        )

        order_info = order_data_specific_day_concatenated[
            order_data_specific_day_concatenated["order_id"] == current_order_id
        ]
        order_info: pd.Series = order_info.iloc[0]
        current_order_datetime = order_info["date"]

        if current_order_datetime != self.previous_order_date:
            print(
                f"The date of Current Order {current_order_datetime} is different from Previous Order {self.previous_order_date}"
            )
            print("Need to set update driver set to empty")
            self.driver_manager.update_driver_set = (
                self.driver_manager.update_driver_set.head(0)
            )

        # ---------------------------------------------------
        order = Order(
            order_id=order_info["order_id"],
            datetime_str=order_info["datetime"],
            pickup_area=order_info["pickup_area2"],
            dropoff_area=order_info["dropoff_area2"],
            pickup_lat=order_info["pickup_lat"],
            pickup_lon=order_info["pickup_lon"],
            dropoff_lat=order_info["dropoff_lat"],
            dropoff_lon=order_info["dropoff_lon"],
            customer_price=order_info["customer_price"],
            commissionPercent=action,
            complete_time=order_info["complete_time"],
            weather_service=self.weather_service,
        )
        print(order)

        # ---------------------------------------------------
        accept_order = self.driver_manager.get_driver_attampt(order=order)
        if accept_order:
            reward = order.platform_revenue
        else:
            reward = 0
        # ---------------------------------------------------
        # update current order index for the next order
        self.current_order_index += 1
        self.previous_order_date = current_order_datetime
        print(f"Update current_order_index to {self.current_order_index}")

        # ---------------------------------------------------
        # check the termination condition
        if self.current_order_index >= self.order_length:
            terminated = True
            print("Reach terminated condition: Finish simulating all the orders.")
        else:
            terminated = False

        # ---------------------------------------------------
        # no truncated condition
        truncated = False

        return self.state, reward, terminated, truncated, {}

    def render(self, mode="human"):
        print(f"Step: {self.steps}, State: {self.state}")

    def close(self):
        pass

    def _get_order_data_specific_day_concatenated(self):
        order_data_columns = [
            "order_id",
            "datetime",
            "date",
            "pickup_area2",
            "dropoff_area2",
            "pickup_lat",
            "pickup_lon",
            "dropoff_lat",
            "dropoff_lon",
            "customer_price",
            "complete_time",
        ]
        valid_days = self.order_data["date"].unique().tolist()
        random.shuffle(valid_days)
        # Initialize an empty list to store processed dataframes
        all_processed_days_data = []

        for day in valid_days:  # Loop through each valid day
            order_data_specific_day = self.order_data[
                self.order_data["date"] == day
            ]  # Use the current day from the loop
            order_data_specific_day = order_data_specific_day.dropna(
                subset=order_data_columns
            )
            order_data_specific_day = order_data_specific_day.sort_values(
                "datetime", ascending=True
            )
            order_data_specific_day = order_data_specific_day[order_data_columns]
            all_processed_days_data.append(
                order_data_specific_day
            )  # Append the processed dataframe for the current day
        # Concatenate all dataframes in the list
        order_data_specific_day_concatenated = pd.concat(all_processed_days_data)

        return order_data_specific_day_concatenated

# %% [markdown]
# ---

# %% [markdown]
# ## Test Delivery Enviornment

# %%
schedule_data = pd.read_csv("./data/driver_schedule.csv", engine="pyarrow")
driver_data = pd.read_csv("./data/driver_update2.csv", engine="pyarrow")
order_data = pd.read_csv("./data/order.csv", engine="pyarrow")
order_driver_data = pd.read_csv("./data/order_driver.csv", engine="pyarrow")
weather_service = WeatherService(weather_csv_path="./data/weather.csv")

# %%
model_output_folder = "./out"
os.makedirs(model_output_folder, exist_ok=True)
model_path = "./Out/acceptance_model.pkl"

# if the model exists, decide if re-train the model is needed
retrain_model: bool = False

if os.path.exists(model_path) and not retrain_model:
    print(f"Model found at {model_path}. Loading model...")
    # with open(model_path, "rb") as f:
    #     model = pickle.load(f)
    model = joblib.load(model_path)
    print("Model loaded successfully.")
# Out:
# Model found at ./Out/acceptance_model.pkl. Loading model...
# Model loaded successfully.

# %%
# date_list = [
#     datetime.date(2025, 4, 11),
#     datetime.date(2025, 4, 18),
# ]

# env = DeliveryEnv(
#     order_data=order_data[order_data["date"].isin(date_list)],
#     driver_data=driver_data,
#     order_driver_data=order_driver_data,
#     schedule_data=schedule_data,
#     acceptance_model=model,
#     weather_service=weather_service,
# )

env = DeliveryEnv(
    order_data=order_data,
    driver_data=driver_data,
    order_driver_data=order_driver_data,
    schedule_data=schedule_data,
    acceptance_model=model,
    weather_service=weather_service,
)

# %%
while True:
    state, reward, terminated, truncated, info = step_res = env.step(0.2)
    if terminated:
        break
# Out:
# The date of Current Order 2025-04-11 is different from Previous Order None
# Need to set update driver set to empty
# Order(
#     order_id=4871106,
#     datetime=2025-04-11 08:23:19,
#     pickup_area=407.0,
#     dropoff_area=110.0,
#     pickup_lat=32.6533674,
#     pickup_lon=51.7195826,
#     dropoff_lat=32.5229111,
#     dropoff_lon=51.8516826,
#     customer_price=505000.00,
#     commissionPercent=0.20,
#     driver_commission=101000.00,
#     platform_revenue=404000.00,
#     hour_of_day=8
#     weather_code=0.0
#     complete_time=48.71666666666667
# )
# No new drivers from update_driver_set with matching 'driver_area' ('407.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 13301.0 is initialized with location (32.6644833, 51.7364583)
# Driver 13301.0 can work at 2025-04-11 08:00.
# The distance calculated by geodesic is 2006.4726694183476
# Features input to the model for prediction:
# {'commission': [np.float64(101000.0)], 'driver_distance': [2006.4726694183476], 'hour': [8], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 13301.0 accept the order with probability of 0.58 and threshold 0.5674895130659173
# Add driver record: Driver 13301.0 has accepted 4871106 at 2025-04-11 08:23:19
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 13301.0
# Update current_order_index to 1
# Order(
#     order_id=4871108,
#     datetime=2025-04-11 08:36:06,
#     pickup_area=691.0,
#     dropoff_area=403.0,
#     pickup_lat=32.7263115,
#     pickup_lon=51.6589383,
#     dropoff_lat=32.6511774,
#     dropoff_lon=51.6766509,
#     customer_price=78000.00,
#     commissionPercent=0.20,
#     driver_commission=15600.00,
#     platform_revenue=62400.00,
#     hour_of_day=8
#     weather_code=0.0
#     complete_time=21.6
# )
# No new drivers from update_driver_set with matching 'driver_area' ('691.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 19291.0 is initialized with location (32.7231367, 51.6614123)
# Driver 19291.0 can work at 2025-04-11 08:00.
# The distance calculated by geodesic is 421.6032760396453
# Features input to the model for prediction:
# {'commission': [np.float64(15600.0)], 'driver_distance': [421.6032760396453], 'hour': [8], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 19291.0 accept the order with probability of 0.31 and threshold 0.19203971346877524
# Add driver record: Driver 19291.0 has accepted 4871108 at 2025-04-11 08:36:06
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 19291.0
# Update current_order_index to 2
# Order(
#     order_id=4871109,
#     datetime=2025-04-11 08:48:45,
#     pickup_area=594.0,
#     dropoff_area=329.0,
#     pickup_lat=32.7002067,
#     pickup_lon=51.6972183,
#     dropoff_lat=32.6263717,
#     dropoff_lon=51.6647759,
#     customer_price=232000.00,
#     commissionPercent=0.20,
#     driver_commission=46400.00,
#     platform_revenue=185600.00,
#     hour_of_day=8
#     weather_code=0.0
#     complete_time=58.46666666666667
# )
# No new drivers from update_driver_set with matching 'driver_area' ('594.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 20813.0 is initialized with location (32.714602, 51.6975856)
# Driver 20813.0 can work at 2025-04-11 08:00.
# The distance calculated by geodesic is 1596.7995744328953
# Features input to the model for prediction:
# {'commission': [np.float64(46400.0)], 'driver_distance': [1596.7995744328953], 'hour': [8], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 20813.0 did not accept the order with probability of 0.2 and threshold 0.7976720931294957
# Driver 21506.0 is initialized with location (32.6979754, 51.7065976)
# Driver 21506.0 can work at 2025-04-11 08:00.
# The distance calculated by geodesic is 913.636681793343
# Features input to the model for prediction:
# {'commission': [np.float64(46400.0)], 'driver_distance': [913.636681793343], 'hour': [8], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 21506.0 did not accept the order with probability of 0.36 and threshold 0.6276386490000949
# Driver 17475.0 is initialized with location (32.7050981, 51.6759851)
# Driver 17475.0 can work at 2025-04-11 08:00.
# The distance calculated by geodesic is 2063.515609950448
# Features input to the model for prediction:
# {'commission': [np.float64(46400.0)], 'driver_distance': [2063.515609950448], 'hour': [8], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 17475.0 accept the order with probability of 0.67 and threshold 0.17849267846876282
# Add driver record: Driver 17475.0 has accepted 4871109 at 2025-04-11 08:48:45
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 17475.0
# Update current_order_index to 3
# Order(
#     order_id=4871110,
#     datetime=2025-04-11 08:48:53,
#     pickup_area=440.0,
#     dropoff_area=398.0,
#     pickup_lat=32.6560171,
#     pickup_lon=51.6672941,
#     dropoff_lat=32.653969,
#     dropoff_lon=51.627681,
#     customer_price=198000.00,
#     commissionPercent=0.20,
#     driver_commission=39600.00,
#     platform_revenue=158400.00,
#     hour_of_day=8
#     weather_code=0.0
#     complete_time=35.583333333333336
# )
# No new drivers from update_driver_set with matching 'driver_area' ('440.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 8955.0 is initialized with location (32.6733872, 51.6604444)
# Driver 8955.0 can work at 2025-04-11 08:00.
# The distance calculated by geodesic is 2030.6538649718525
# Features input to the model for prediction:
# {'commission': [np.float64(39600.0)], 'driver_distance': [2030.6538649718525], 'hour': [8], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 8955.0 accept the order with probability of 0.65 and threshold 0.15356421527777298
# Add driver record: Driver 8955.0 has accepted 4871110 at 2025-04-11 08:48:53
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 8955.0
# Update current_order_index to 4
# Order(
#     order_id=4871111,
#     datetime=2025-04-11 09:26:26,
#     pickup_area=480.0,
#     dropoff_area=261.0,
#     pickup_lat=32.6678694,
#     pickup_lon=51.6734865,
#     dropoff_lat=32.6134674,
#     dropoff_lon=51.8068851,
#     customer_price=296000.00,
#     commissionPercent=0.20,
#     driver_commission=59200.00,
#     platform_revenue=236800.00,
#     hour_of_day=9
#     weather_code=0.0
#     complete_time=44.016666666666666
# )
# No new drivers from update_driver_set with matching 'driver_area' ('480.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 19458.0 is initialized with location (32.6656317, 51.6621566)
# Driver 19458.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1091.365857508198
# Features input to the model for prediction:
# {'commission': [np.float64(59200.0)], 'driver_distance': [1091.365857508198], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 19458.0 accept the order with probability of 0.32 and threshold 0.009084813990192453
# Add driver record: Driver 19458.0 has accepted 4871111 at 2025-04-11 09:26:26
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 19458.0
# Update current_order_index to 5
# Order(
#     order_id=4871112,
#     datetime=2025-04-11 09:26:57,
#     pickup_area=364.0,
#     dropoff_area=518.0,
#     pickup_lat=32.6368368,
#     pickup_lon=51.6557427,
#     dropoff_lat=32.67988,
#     dropoff_lon=51.6574057,
#     customer_price=49000.00,
#     commissionPercent=0.20,
#     driver_commission=9800.00,
#     platform_revenue=39200.00,
#     hour_of_day=9
#     weather_code=0.0
#     complete_time=10.1
# )
# No new drivers from update_driver_set with matching 'driver_area' ('364.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 15967.0 is initialized with location (32.6543028, 51.6598249)
# Driver 15967.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1974.4528453179175
# Features input to the model for prediction:
# {'commission': [np.float64(9800.0)], 'driver_distance': [1974.4528453179175], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(1.966666667)]}
# Driver 15967.0 accept the order with probability of 0.38 and threshold 0.21078957105839846
# Add driver record: Driver 15967.0 has accepted 4871112 at 2025-04-11 09:26:57
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 15967.0
# Update current_order_index to 6
# Order(
#     order_id=4871113,
#     datetime=2025-04-11 09:27:30,
#     pickup_area=284.0,
#     dropoff_area=585.0,
#     pickup_lat=32.615239,
#     pickup_lon=51.6635814,
#     dropoff_lat=32.7043779,
#     dropoff_lon=51.6123902,
#     customer_price=290000.00,
#     commissionPercent=0.20,
#     driver_commission=58000.00,
#     platform_revenue=232000.00,
#     hour_of_day=9
#     weather_code=0.0
#     complete_time=33.68333333333334
# )
# No new drivers from update_driver_set with matching 'driver_area' ('284.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 21181.0 is initialized with location (32.6043067, 51.6754)
# Driver 21181.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1643.2971908899299
# Features input to the model for prediction:
# {'commission': [np.float64(58000.0)], 'driver_distance': [1643.2971908899299], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 21181.0 did not accept the order with probability of 0.21 and threshold 0.8817090635226515
# Driver 2531.0 is initialized with location (32.6260707, 51.6528426)
# Driver 2531.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1568.013130424052
# Features input to the model for prediction:
# {'commission': [np.float64(58000.0)], 'driver_distance': [1568.013130424052], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 2531.0 did not accept the order with probability of 0.14 and threshold 0.7872437148869165
# Update current_order_index to 7
# Order(
#     order_id=4871114,
#     datetime=2025-04-11 09:31:52,
#     pickup_area=479.0,
#     dropoff_area=560.0,
#     pickup_lat=32.6659071,
#     pickup_lon=51.6589311,
#     dropoff_lat=32.6873136,
#     dropoff_lon=51.6961065,
#     customer_price=53000.00,
#     commissionPercent=0.20,
#     driver_commission=10600.00,
#     platform_revenue=42400.00,
#     hour_of_day=9
#     weather_code=0.0
#     complete_time=50.9
# )
# No new drivers from update_driver_set with matching 'driver_area' ('479.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [15967.0]
# Driver pool has been randomized.
# Driver 13361.0 is initialized with location (32.675278, 51.6493455)
# Driver 13361.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1374.1881011461853
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1374.1881011461853], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.15)]}
# Driver 13361.0 did not accept the order with probability of 0.19 and threshold 0.6370987128573029
# Driver 15967.0 is initialized with location (32.67988, 51.6574057)
# Driver 15967.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1556.1671483105326
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1556.1671483105326], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(12.066666667)]}
# Driver 15967.0 did not accept the order with probability of 0.17 and threshold 0.8532277095424516
# Driver 21589.0 is initialized with location (32.6762423, 51.650563)
# Driver 21589.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1389.1625019082928
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1389.1625019082928], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 21589.0 did not accept the order with probability of 0.15 and threshold 0.2109056185922744
# Driver 20165.0 is initialized with location (32.6635067, 51.6395767)
# Driver 20165.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1834.9530161211349
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1834.9530161211349], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 20165.0 did not accept the order with probability of 0.29 and threshold 0.6007545183202215
# Driver 9353.0 is initialized with location (32.6572774, 51.6692176)
# Driver 9353.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1359.0565889133522
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1359.0565889133522], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(17.38333333)]}
# Driver 9353.0 did not accept the order with probability of 0.36 and threshold 0.7567397456430661
# Driver 21589.0 is initialized with location (32.6754543, 51.649636)
# Driver 21589.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1371.5513913156299
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1371.5513913156299], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(4.0)]}
# Driver 21589.0 did not accept the order with probability of 0.16 and threshold 0.5019035575971478
# Driver 9353.0 is initialized with location (32.6573157, 51.669318)
# Driver 9353.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1362.7868900908197
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1362.7868900908197], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(33.4)]}
# Driver 9353.0 did not accept the order with probability of 0.42 and threshold 0.8037759222721144
# Driver 15967.0 is initialized with location (32.67988, 51.6574057)
# Driver 15967.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1556.1671483105326
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1556.1671483105326], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(12.066666667)]}
# Driver 15967.0 did not accept the order with probability of 0.17 and threshold 0.9115794264049853
# Driver 9353.0 is initialized with location (32.6570505, 51.6693787)
# Driver 9353.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1387.525655481007
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1387.525655481007], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(9.366666667)]}
# Driver 9353.0 did not accept the order with probability of 0.14 and threshold 0.6802504836601043
# Driver 13361.0 is initialized with location (32.6743012, 51.6511919)
# Driver 13361.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1180.4837293902146
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1180.4837293902146], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(28.85)]}
# Driver 13361.0 did not accept the order with probability of 0.49 and threshold 0.710414667398716
# Driver 9353.0 is initialized with location (32.6573556, 51.6692929)
# Driver 9353.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1358.0105110550005
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1358.0105110550005], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(13.36666667)]}
# Driver 9353.0 did not accept the order with probability of 0.3 and threshold 0.6564648100824444
# Driver 9353.0 is initialized with location (32.6572873, 51.6692265)
# Driver 9353.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1358.8769171521158
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1358.8769171521158], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(21.36666667)]}
# Driver 9353.0 did not accept the order with probability of 0.49 and threshold 0.8166311229859881
# Driver 9353.0 is initialized with location (32.6573433, 51.6693079)
# Driver 9353.0 can work at 2025-04-11 09:00.
# The distance calculated by geodesic is 1359.9703016546177
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1359.9703016546177], 'hour': [9], 'weather_code': [0.0], 'work_time_minutes': [np.float64(29.38333333)]}
# Driver 9353.0 accept the order with probability of 0.55 and threshold 0.04812428288513082
# Add driver record: Driver 9353.0 has accepted 4871114 at 2025-04-11 09:31:52
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 9353.0
# Update current_order_index to 8
# Order(
#     order_id=4871118,
#     datetime=2025-04-11 10:03:36,
#     pickup_area=515.0,
#     dropoff_area=365.0,
#     pickup_lat=32.6761566,
#     pickup_lon=51.6301524,
#     dropoff_lat=32.640678,
#     dropoff_lon=51.6668336,
#     customer_price=187000.00,
#     commissionPercent=0.20,
#     driver_commission=37400.00,
#     platform_revenue=149600.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=16.916666666666668
# )
# No new drivers from update_driver_set with matching 'driver_area' ('515.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 15880.0 is initialized with location (32.6637416, 51.6397688)
# Driver 15880.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1645.9724703916327
# Features input to the model for prediction:
# {'commission': [np.float64(37400.0)], 'driver_distance': [1645.9724703916327], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 15880.0 did not accept the order with probability of 0.45 and threshold 0.5831556353772994
# Driver 8968.0 is initialized with location (32.6852583, 51.6364252)
# Driver 8968.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1168.3056653272965
# Features input to the model for prediction:
# {'commission': [np.float64(37400.0)], 'driver_distance': [1168.3056653272965], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(4.583333333)]}
# Driver 8968.0 did not accept the order with probability of 0.11 and threshold 0.42167183128675856
# Driver 12266.0 is initialized with location (32.6840519, 51.6088651)
# Driver 12266.0 is not scheduled to work at 2025-04-11 10:00.
# Driver 12266.0 is initialized with location (32.684051, 51.6088646)
# Driver 12266.0 is not scheduled to work at 2025-04-11 10:00.
# Driver 15880.0 is initialized with location (32.6671886, 51.6164965)
# Driver 15880.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1621.6645203649052
# Features input to the model for prediction:
# {'commission': [np.float64(37400.0)], 'driver_distance': [1621.6645203649052], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(4.0)]}
# Driver 15880.0 did not accept the order with probability of 0.08 and threshold 0.31206892419627585
# Driver 12266.0 is initialized with location (32.6841312, 51.6089495)
# Driver 12266.0 is not scheduled to work at 2025-04-11 10:00.
# Driver 16463.0 is initialized with location (32.6926001, 51.6340351)
# Driver 16463.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1859.5661925597522
# Features input to the model for prediction:
# {'commission': [np.float64(37400.0)], 'driver_distance': [1859.5661925597522], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 16463.0 did not accept the order with probability of 0.26 and threshold 0.9539875698099366
# Driver 15880.0 is initialized with location (32.6672563, 51.6163229)
# Driver 15880.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1629.999001232321
# Features input to the model for prediction:
# {'commission': [np.float64(37400.0)], 'driver_distance': [1629.999001232321], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(8.0)]}
# Driver 15880.0 accept the order with probability of 0.06 and threshold 0.004906461506928639
# Add driver record: Driver 15880.0 has accepted 4871118 at 2025-04-11 10:03:36
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 15880.0
# Update current_order_index to 9
# Order(
#     order_id=4871119,
#     datetime=2025-04-11 10:07:45,
#     pickup_area=331.0,
#     dropoff_area=208.0,
#     pickup_lat=32.6312909,
#     pickup_lon=51.6822256,
#     dropoff_lat=32.5920024,
#     dropoff_lon=51.6663542,
#     customer_price=183000.00,
#     commissionPercent=0.20,
#     driver_commission=36600.00,
#     platform_revenue=146400.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=16.21666666666667
# )
# No new drivers from update_driver_set with matching 'driver_area' ('331.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 17895.0 is initialized with location (32.6292352, 51.6993056)
# Driver 17895.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1618.9366806075707
# Features input to the model for prediction:
# {'commission': [np.float64(36600.0)], 'driver_distance': [1618.9366806075707], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 17895.0 accept the order with probability of 0.39 and threshold 0.35360644965534394
# Add driver record: Driver 17895.0 has accepted 4871119 at 2025-04-11 10:07:45
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 17895.0
# Update current_order_index to 10
# Order(
#     order_id=4871120,
#     datetime=2025-04-11 10:11:22,
#     pickup_area=483.0,
#     dropoff_area=593.0,
#     pickup_lat=32.670435,
#     pickup_lon=51.6971117,
#     dropoff_lat=32.6955083,
#     dropoff_lon=51.6870833,
#     customer_price=56000.00,
#     commissionPercent=0.20,
#     driver_commission=11200.00,
#     platform_revenue=44800.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=14.066666666666666
# )
# No new drivers from update_driver_set with matching 'driver_area' ('483.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 442.0 is initialized with location (32.66489, 51.6995033)
# Driver 442.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 654.575453263407
# Features input to the model for prediction:
# {'commission': [np.float64(11200.0)], 'driver_distance': [654.575453263407], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 442.0 did not accept the order with probability of 0.19 and threshold 0.481000600230131
# Driver 5948.0 is initialized with location (32.682545, 51.6931556)
# Driver 5948.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1393.3001554382126
# Features input to the model for prediction:
# {'commission': [np.float64(11200.0)], 'driver_distance': [1393.3001554382126], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(39.83333333)]}
# Driver 5948.0 accept the order with probability of 0.28 and threshold 0.14358205565394033
# Add driver record: Driver 5948.0 has accepted 4871120 at 2025-04-11 10:11:22
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 5948.0
# Update current_order_index to 11
# Order(
#     order_id=4871122,
#     datetime=2025-04-11 10:12:48,
#     pickup_area=519.0,
#     dropoff_area=441.0,
#     pickup_lat=32.6755727,
#     pickup_lon=51.6739353,
#     dropoff_lat=32.6622428,
#     dropoff_lon=51.6783504,
#     customer_price=43000.00,
#     commissionPercent=0.20,
#     driver_commission=8600.00,
#     platform_revenue=34400.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=12.483333333333333
# )
# No new drivers from update_driver_set with matching 'driver_area' ('519.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [5948.0, 9353.0]
# Driver pool has been randomized.
# Driver 4936.0 is initialized with location (32.6827797, 51.6799966)
# Driver 4936.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 980.803896567136
# Features input to the model for prediction:
# {'commission': [np.float64(8600.0)], 'driver_distance': [980.803896567136], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(3.416666667)]}
# Driver 4936.0 did not accept the order with probability of 0.15 and threshold 0.9468216664785046
# Driver 9353.0 is initialized with location (32.6873136, 51.6961065)
# Driver 9353.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 2453.400692549954
# Features input to the model for prediction:
# {'commission': [np.float64(8600.0)], 'driver_distance': [2453.400692549954], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(80.28333333)]}
# Driver 9353.0 accept the order with probability of 0.54 and threshold 0.0447355279033681
# Add driver record: Driver 9353.0 has accepted 4871122 at 2025-04-11 10:12:48
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 9353.0
# Update current_order_index to 12
# Order(
#     order_id=4871123,
#     datetime=2025-04-11 10:15:12,
#     pickup_area=591.0,
#     dropoff_area=414.0,
#     pickup_lat=32.6998856,
#     pickup_lon=51.6746699,
#     dropoff_lat=32.6502873,
#     dropoff_lon=51.7858952,
#     customer_price=99000.00,
#     commissionPercent=0.20,
#     driver_commission=19800.00,
#     platform_revenue=79200.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=41.43333333333333
# )
# No new drivers from update_driver_set with matching 'driver_area' ('591.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 13965.0 is initialized with location (32.7224342, 51.6686039)
# Driver 13965.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 2564.4831929799693
# Features input to the model for prediction:
# {'commission': [np.float64(19800.0)], 'driver_distance': [2564.4831929799693], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(1.05)]}
# Driver 13965.0 did not accept the order with probability of 0.36 and threshold 0.6688979936299154
# Driver 13458.0 is initialized with location (32.7150509, 51.6569884)
# Driver 13458.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 2361.5465360475328
# Features input to the model for prediction:
# {'commission': [np.float64(19800.0)], 'driver_distance': [2361.5465360475328], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 13458.0 accept the order with probability of 0.68 and threshold 0.6043851271468706
# Add driver record: Driver 13458.0 has accepted 4871123 at 2025-04-11 10:15:12
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 13458.0
# Update current_order_index to 13
# Order(
#     order_id=4871124,
#     datetime=2025-04-11 10:19:16,
#     pickup_area=403.0,
#     dropoff_area=328.0,
#     pickup_lat=32.650588,
#     pickup_lon=51.6822138,
#     dropoff_lat=32.6293188,
#     dropoff_lon=51.6532946,
#     customer_price=53000.00,
#     commissionPercent=0.20,
#     driver_commission=10600.00,
#     platform_revenue=42400.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=15.05
# )
# No new drivers from update_driver_set with matching 'driver_area' ('403.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [9353.0]
# Driver pool has been randomized.
# Driver 21513.0 is initialized with location (32.6535376, 51.6988175)
# Driver 21513.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1591.7045171375416
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1591.7045171375416], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(7.9)]}
# Driver 21513.0 did not accept the order with probability of 0.07 and threshold 0.5706944270716264
# Driver 20034.0 is initialized with location (32.6485434, 51.665559)
# Driver 20034.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1578.9338098081585
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1578.9338098081585], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 20034.0 did not accept the order with probability of 0.23 and threshold 0.7671458850734924
# Driver 9353.0 is initialized with location (32.6622428, 51.6783504)
# Driver 9353.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1342.3540564482205
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1342.3540564482205], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(92.76666666333334)]}
# Driver 9353.0 did not accept the order with probability of 0.01 and threshold 0.22814637476900257
# Driver 10666.0 is initialized with location (32.6550971, 51.6996675)
# Driver 10666.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1712.1138180650908
# Features input to the model for prediction:
# {'commission': [np.float64(10600.0)], 'driver_distance': [1712.1138180650908], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 10666.0 did not accept the order with probability of 0.17 and threshold 0.930587913897378
# Update current_order_index to 14
# Order(
#     order_id=4871125,
#     datetime=2025-04-11 10:23:38,
#     pickup_area=443.0,
#     dropoff_area=149.0,
#     pickup_lat=32.6633382,
#     pickup_lon=51.6991344,
#     dropoff_lat=32.5504126,
#     dropoff_lon=51.745647,
#     customer_price=394000.00,
#     commissionPercent=0.20,
#     driver_commission=78800.00,
#     platform_revenue=315200.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=39.9
# )
# No new drivers from update_driver_set with matching 'driver_area' ('443.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 9781.0 is initialized with location (32.6451346, 51.6921382)
# Driver 9781.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 2122.769195003739
# Features input to the model for prediction:
# {'commission': [np.float64(78800.0)], 'driver_distance': [2122.769195003739], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 9781.0 accept the order with probability of 0.75 and threshold 0.7466052427721002
# Add driver record: Driver 9781.0 has accepted 4871125 at 2025-04-11 10:23:38
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 9781.0
# Update current_order_index to 15
# Order(
#     order_id=4871126,
#     datetime=2025-04-11 10:27:56,
#     pickup_area=327.0,
#     dropoff_area=562.0,
#     pickup_lat=32.6261074,
#     pickup_lon=51.6432762,
#     dropoff_lat=32.6902267,
#     dropoff_lon=51.7196233,
#     customer_price=92000.00,
#     commissionPercent=0.20,
#     driver_commission=18400.00,
#     platform_revenue=73600.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=29.5
# )
# No new drivers from update_driver_set with matching 'driver_area' ('327.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 14071.0 is initialized with location (32.6187795, 51.6130148)
# Driver 14071.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 2953.9879278551157
# Features input to the model for prediction:
# {'commission': [np.float64(18400.0)], 'driver_distance': [2953.9879278551157], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(4.416666667)]}
# Driver 14071.0 accept the order with probability of 0.32 and threshold 0.0471199731617159
# Add driver record: Driver 14071.0 has accepted 4871126 at 2025-04-11 10:27:56
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 14071.0
# Update current_order_index to 16
# Order(
#     order_id=4871127,
#     datetime=2025-04-11 10:31:24,
#     pickup_area=483.0,
#     dropoff_area=404.0,
#     pickup_lat=32.6689467,
#     pickup_lon=51.7044667,
#     dropoff_lat=32.65187,
#     dropoff_lon=51.6878905,
#     customer_price=47000.00,
#     commissionPercent=0.20,
#     driver_commission=9400.00,
#     platform_revenue=37600.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=9.883333333333333
# )
# No new drivers from update_driver_set with matching 'driver_area' ('483.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [5948.0]
# Driver pool has been randomized.
# Driver 5948.0 is initialized with location (32.6955083, 51.6870833)
# Driver 5948.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 3366.725415025934
# Features input to the model for prediction:
# {'commission': [np.float64(9400.0)], 'driver_distance': [3366.725415025934], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(53.899999996666665)]}
# Driver 5948.0 did not accept the order with probability of 0.53 and threshold 0.9596397302833614
# Driver 442.0 is initialized with location (32.6663694, 51.7020683)
# Driver 442.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 363.73898134640075
# Features input to the model for prediction:
# {'commission': [np.float64(9400.0)], 'driver_distance': [363.73898134640075], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(30.26666667)]}
# Driver 442.0 did not accept the order with probability of 0.21 and threshold 0.7403613831736464
# Driver 956.0 is initialized with location (32.6769096, 51.7247584)
# Driver 956.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 2098.174326627628
# Features input to the model for prediction:
# {'commission': [np.float64(9400.0)], 'driver_distance': [2098.174326627628], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 956.0 accept the order with probability of 0.74 and threshold 0.3663704553937247
# Add driver record: Driver 956.0 has accepted 4871127 at 2025-04-11 10:31:24
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 956.0
# Update current_order_index to 17
# Order(
#     order_id=4871129,
#     datetime=2025-04-11 10:34:01,
#     pickup_area=402.0,
#     dropoff_area=515.0,
#     pickup_lat=32.6533733,
#     pickup_lon=51.6673867,
#     dropoff_lat=32.6763733,
#     dropoff_lon=51.6321033,
#     customer_price=52000.00,
#     commissionPercent=0.20,
#     driver_commission=10400.00,
#     platform_revenue=41600.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=17.033333333333335
# )
# No new drivers from update_driver_set with matching 'driver_area' ('402.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [9353.0, 15967.0]
# Driver pool has been randomized.
# Driver 20165.0 is initialized with location (32.6586185, 51.6505068)
# Driver 20165.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1687.0279037187531
# Features input to the model for prediction:
# {'commission': [np.float64(10400.0)], 'driver_distance': [1687.0279037187531], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(24.08333333)]}
# Driver 20165.0 did not accept the order with probability of 0.11 and threshold 0.29463349859764787
# Driver 19815.0 is initialized with location (32.6617167, 51.6501557)
# Driver 19815.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1862.5641951463167
# Features input to the model for prediction:
# {'commission': [np.float64(10400.0)], 'driver_distance': [1862.5641951463167], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(2.083333333)]}
# Driver 19815.0 did not accept the order with probability of 0.17 and threshold 0.5756466511166792
# Driver 9353.0 is initialized with location (32.6622428, 51.6783504)
# Driver 9353.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1423.1544540499895
# Features input to the model for prediction:
# {'commission': [np.float64(10400.0)], 'driver_distance': [1423.1544540499895], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(92.76666666333334)]}
# Driver 9353.0 did not accept the order with probability of 0.12 and threshold 0.13675623650807012
# Driver 15967.0 is initialized with location (32.67988, 51.6574057)
# Driver 15967.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 3085.0512494378254
# Features input to the model for prediction:
# {'commission': [np.float64(10400.0)], 'driver_distance': [3085.0512494378254], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(12.066666667)]}
# Driver 15967.0 accept the order with probability of 0.39 and threshold 0.15660234164040732
# Add driver record: Driver 15967.0 has accepted 4871129 at 2025-04-11 10:34:01
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 15967.0
# Update current_order_index to 18
# Order(
#     order_id=4871130,
#     datetime=2025-04-11 10:34:30,
#     pickup_area=443.0,
#     dropoff_area=208.0,
#     pickup_lat=32.6633859,
#     pickup_lon=51.7010252,
#     dropoff_lat=32.5885163,
#     dropoff_lon=51.6705914,
#     customer_price=87000.00,
#     commissionPercent=0.20,
#     driver_commission=17400.00,
#     platform_revenue=69600.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=18.833333333333332
# )
# Added new drivers to the pool based on matching 'driver_area' ('443.0'): [9781.0]
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [9781.0]
# Driver pool has been randomized.
# Driver 11671.0 is initialized with location (32.6771041, 51.7051797)
# Driver 11671.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1570.4459098262487
# Features input to the model for prediction:
# {'commission': [np.float64(17400.0)], 'driver_distance': [1570.4459098262487], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(3.116666667)]}
# Driver 11671.0 did not accept the order with probability of 0.29 and threshold 0.41650657307043726
# Driver 12626.0 is initialized with location (32.6493938, 51.7090176)
# Driver 12626.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1723.3605768534708
# Features input to the model for prediction:
# {'commission': [np.float64(17400.0)], 'driver_distance': [1723.3605768534708], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 12626.0 did not accept the order with probability of 0.16 and threshold 0.4418252498332772
# Driver 9781.0 is initialized with location (32.5504126, 51.745647)
# Driver 9781.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 13210.042936631085
# Features input to the model for prediction:
# {'commission': [np.float64(17400.0)], 'driver_distance': [13210.042936631085], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(39.9)]}
# Driver 9781.0 did not accept the order with probability of 0.51 and threshold 0.9319957005509542
# Driver 2140.0 is initialized with location (32.6492509, 51.6933267)
# Driver 2140.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1725.9252462178677
# Features input to the model for prediction:
# {'commission': [np.float64(17400.0)], 'driver_distance': [1725.9252462178677], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 2140.0 did not accept the order with probability of 0.16 and threshold 0.3424527235278766
# Driver 21513.0 is initialized with location (32.6535458, 51.6988113)
# Driver 21513.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1110.839489530441
# Features input to the model for prediction:
# {'commission': [np.float64(17400.0)], 'driver_distance': [1110.839489530441], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(23.13333333)]}
# Driver 21513.0 accept the order with probability of 0.22 and threshold 0.042059688663548034
# Add driver record: Driver 21513.0 has accepted 4871130 at 2025-04-11 10:34:30
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 21513.0
# Update current_order_index to 19
# Order(
#     order_id=4871131,
#     datetime=2025-04-11 10:39:32,
#     pickup_area=402.0,
#     dropoff_area=330.0,
#     pickup_lat=32.6531092,
#     pickup_lon=51.6674124,
#     dropoff_lat=32.6282171,
#     dropoff_lon=51.6712863,
#     customer_price=48000.00,
#     commissionPercent=0.20,
#     driver_commission=9600.00,
#     platform_revenue=38400.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=11.283333333333333
# )
# No new drivers from update_driver_set with matching 'driver_area' ('402.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [15967.0]
# Driver pool has been randomized.
# Driver 15967.0 is initialized with location (32.6763733, 51.6321033)
# Driver 15967.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 4198.409806584999
# Features input to the model for prediction:
# {'commission': [np.float64(9600.0)], 'driver_distance': [4198.409806584999], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(29.100000000333335)]}
# Driver 15967.0 did not accept the order with probability of 0.39 and threshold 0.6129512144805256
# Driver 15967.0 is initialized with location (32.6763733, 51.6321033)
# Driver 15967.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 4198.409806584999
# Features input to the model for prediction:
# {'commission': [np.float64(9600.0)], 'driver_distance': [4198.409806584999], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(29.100000000333335)]}
# Driver 15967.0 did not accept the order with probability of 0.39 and threshold 0.5361356900976848
# Driver 21313.0 is initialized with location (32.658328, 51.653094)
# Driver 21313.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1462.6488591753048
# Features input to the model for prediction:
# {'commission': [np.float64(9600.0)], 'driver_distance': [1462.6488591753048], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 21313.0 did not accept the order with probability of 0.2 and threshold 0.6712767452075726
# Update current_order_index to 20
# Order(
#     order_id=4871132,
#     datetime=2025-04-11 10:40:47,
#     pickup_area=442.0,
#     dropoff_area=365.0,
#     pickup_lat=32.6647655,
#     pickup_lon=51.6904807,
#     dropoff_lat=32.635017,
#     dropoff_lon=51.6713292,
#     customer_price=48000.00,
#     commissionPercent=0.20,
#     driver_commission=9600.00,
#     platform_revenue=38400.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=16.06666666666667
# )
# No new drivers from update_driver_set with matching 'driver_area' ('442.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 4936.0 is initialized with location (32.6626192, 51.6790121)
# Driver 4936.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1101.841184409487
# Features input to the model for prediction:
# {'commission': [np.float64(9600.0)], 'driver_distance': [1101.841184409487], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(27.98333333)]}
# Driver 4936.0 did not accept the order with probability of 0.19 and threshold 0.45776862646987215
# Driver 442.0 is initialized with location (32.669861, 51.7006524)
# Driver 442.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1108.910527744926
# Features input to the model for prediction:
# {'commission': [np.float64(9600.0)], 'driver_distance': [1108.910527744926], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(29.43333333)]}
# Driver 442.0 did not accept the order with probability of 0.15 and threshold 0.37463882033413964
# Update current_order_index to 21
# Order(
#     order_id=4871133,
#     datetime=2025-04-11 10:40:48,
#     pickup_area=524.0,
#     dropoff_area=485.0,
#     pickup_lat=32.6769227,
#     pickup_lon=51.7247747,
#     dropoff_lat=32.6712102,
#     dropoff_lon=51.7166354,
#     customer_price=63000.00,
#     commissionPercent=0.20,
#     driver_commission=12600.00,
#     platform_revenue=50400.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=19.233333333333334
# )
# No new drivers from update_driver_set with matching 'driver_area' ('524.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [956.0]
# Driver pool has been randomized.
# Driver 956.0 is initialized with location (32.65187, 51.6878905)
# Driver 956.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 4437.359176931955
# Features input to the model for prediction:
# {'commission': [np.float64(12600.0)], 'driver_distance': [4437.359176931955], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(9.883333333333333)]}
# Driver 956.0 did not accept the order with probability of 0.41 and threshold 0.47664934738367015
# Driver 6944.0 is initialized with location (32.6846385, 51.7076609)
# Driver 6944.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1818.9114426818635
# Features input to the model for prediction:
# {'commission': [np.float64(12600.0)], 'driver_distance': [1818.9114426818635], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 6944.0 did not accept the order with probability of 0.1 and threshold 0.39643878098261
# Driver 11671.0 is initialized with location (32.6672886, 51.7204435)
# Driver 11671.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1143.0398475213933
# Features input to the model for prediction:
# {'commission': [np.float64(12600.0)], 'driver_distance': [1143.0398475213933], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(9.416666667)]}
# Driver 11671.0 accept the order with probability of 0.21 and threshold 0.20831208215080643
# Add driver record: Driver 11671.0 has accepted 4871133 at 2025-04-11 10:40:48
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 11671.0
# Update current_order_index to 22
# Order(
#     order_id=4871134,
#     datetime=2025-04-11 10:43:04,
#     pickup_area=520.0,
#     dropoff_area=330.0,
#     pickup_lat=32.6829134,
#     pickup_lon=51.6787071,
#     dropoff_lat=32.6310239,
#     dropoff_lon=51.6746214,
#     customer_price=190000.00,
#     commissionPercent=0.20,
#     driver_commission=38000.00,
#     platform_revenue=152000.00,
#     hour_of_day=10
#     weather_code=1.0
#     complete_time=42.516666666666666
# )
# No new drivers from update_driver_set with matching 'driver_area' ('520.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [8955.0, 17475.0, 19458.0]
# Driver pool has been randomized.
# Driver 5884.0 is initialized with location (32.6900313, 51.6884649)
# Driver 5884.0 can work at 2025-04-11 10:00.
# The distance calculated by geodesic is 1208.5221237442368
# Features input to the model for prediction:
# {'commission': [np.float64(38000.0)], 'driver_distance': [1208.5221237442368], 'hour': [10], 'weather_code': [1.0], 'work_time_minutes': [np.float64(0.0)]}
# ...
# Add driver record: Driver 12626.0 has accepted 4883889 at 2025-04-18 21:00:19
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 12626.0
# Update current_order_index to 347
# Order(
#     order_id=4883891,
#     datetime=2025-04-18 21:02:07,
#     pickup_area=519.0,
#     dropoff_area=592.0,
#     pickup_lat=32.6784488,
#     pickup_lon=51.6717736,
#     dropoff_lat=32.7029133,
#     dropoff_lon=51.6802317,
#     customer_price=775000.00,
#     commissionPercent=0.20,
#     driver_commission=155000.00,
#     platform_revenue=620000.00,
#     hour_of_day=21
#     weather_code=3.0
#     complete_time=262.7666666666667
# )
# No new drivers from update_driver_set with matching 'driver_area' ('519.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 6088.0 is initialized with location (32.67854, 51.6717533)
# Driver 6088.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 10.29161502482874
# Features input to the model for prediction:
# {'commission': [np.float64(155000.0)], 'driver_distance': [10.29161502482874], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(51.76666667)]}
# Driver 6088.0 did not accept the order with probability of 0.26 and threshold 0.9398408854229788
# Update current_order_index to 348
# Order(
#     order_id=4883892,
#     datetime=2025-04-18 21:05:27,
#     pickup_area=431.0,
#     dropoff_area=41.0,
#     pickup_lat=32.6629683,
#     pickup_lon=51.5769783,
#     dropoff_lat=32.4788416,
#     dropoff_lon=51.3809565,
#     customer_price=537000.00,
#     commissionPercent=0.20,
#     driver_commission=107400.00,
#     platform_revenue=429600.00,
#     hour_of_day=21
#     weather_code=3.0
#     complete_time=90.63333333333334
# )
# No new drivers from update_driver_set with matching 'driver_area' ('431.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 19494.0 is initialized with location (32.6635297, 51.5813586)
# Driver 19494.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 415.59092429246033
# Features input to the model for prediction:
# {'commission': [np.float64(107400.0)], 'driver_distance': [415.59092429246033], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 19494.0 did not accept the order with probability of 0.31 and threshold 0.9111059131754656
# Driver 19924.0 is initialized with location (32.677515, 51.5864167)
# Driver 19924.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 1840.1700238981603
# Features input to the model for prediction:
# {'commission': [np.float64(107400.0)], 'driver_distance': [1840.1700238981603], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 19924.0 did not accept the order with probability of 0.25 and threshold 0.3211075954241027
# Update current_order_index to 349
# Order(
#     order_id=4883893,
#     datetime=2025-04-18 21:07:35,
#     pickup_area=431.0,
#     dropoff_area=57.0,
#     pickup_lat=32.6623833,
#     pickup_lon=51.5779709,
#     dropoff_lat=32.4897772,
#     dropoff_lon=51.3751768,
#     customer_price=535000.00,
#     commissionPercent=0.20,
#     driver_commission=107000.00,
#     platform_revenue=428000.00,
#     hour_of_day=21
#     weather_code=3.0
#     complete_time=79.93333333333334
# )
# No new drivers from update_driver_set with matching 'driver_area' ('431.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 19494.0 is initialized with location (32.663479, 51.5813594)
# Driver 19494.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 340.2985154548903
# Features input to the model for prediction:
# {'commission': [np.float64(107000.0)], 'driver_distance': [340.2985154548903], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(2.15)]}
# Driver 19494.0 did not accept the order with probability of 0.29 and threshold 0.5661983625782361
# Update current_order_index to 350
# Order(
#     order_id=4883894,
#     datetime=2025-04-18 21:25:15,
#     pickup_area=443.0,
#     dropoff_area=521.0,
#     pickup_lat=32.6632917,
#     pickup_lon=51.6994333,
#     dropoff_lat=32.677755,
#     dropoff_lon=51.6876433,
#     customer_price=50000.00,
#     commissionPercent=0.20,
#     driver_commission=10000.00,
#     platform_revenue=40000.00,
#     hour_of_day=21
#     weather_code=3.0
#     complete_time=6.066666666666666
# )
# Added new drivers to the pool based on matching 'driver_area' ('443.0'): [21614.0]
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [15532.0, 21614.0]
# Driver pool has been randomized.
# Driver 15532.0 is initialized with location (32.5980183, 51.6622433)
# Driver 15532.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 8036.054315823918
# Features input to the model for prediction:
# {'commission': [np.float64(10000.0)], 'driver_distance': [8036.054315823918], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(34.56666666666667)]}
# Driver 15532.0 accept the order with probability of 0.47 and threshold 0.19279575394047244
# Add driver record: Driver 15532.0 has accepted 4883894 at 2025-04-18 21:25:15
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 15532.0
# Update current_order_index to 351
# Order(
#     order_id=4883895,
#     datetime=2025-04-18 21:34:01,
#     pickup_area=558.0,
#     dropoff_area=558.0,
#     pickup_lat=32.6927139,
#     pickup_lon=51.682251,
#     dropoff_lat=32.6927538,
#     dropoff_lon=51.6823482,
#     customer_price=1300000.00,
#     commissionPercent=0.20,
#     driver_commission=260000.00,
#     platform_revenue=1040000.00,
#     hour_of_day=21
#     weather_code=3.0
#     complete_time=5.083333333333333
# )
# No new drivers from update_driver_set with matching 'driver_area' ('558.0') to add.
# update_driver_set has no matched driver ID for existing drivers in the pool, no update from it.
# Driver pool has been randomized.
# Driver 17797.0 is initialized with location (32.6926966, 51.6822094)
# Driver 17797.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 4.3473240123427885
# Features input to the model for prediction:
# {'commission': [np.float64(260000.0)], 'driver_distance': [4.3473240123427885], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 17797.0 did not accept the order with probability of 0.57 and threshold 0.6865825940829404
# Update current_order_index to 352
# Order(
#     order_id=4883896,
#     datetime=2025-04-18 21:44:22,
#     pickup_area=625.0,
#     dropoff_area=327.0,
#     pickup_lat=32.7141953,
#     pickup_lon=51.6665896,
#     dropoff_lat=32.6313447,
#     dropoff_lon=51.6359845,
#     customer_price=94000.00,
#     commissionPercent=0.20,
#     driver_commission=18800.00,
#     platform_revenue=75200.00,
#     hour_of_day=21
#     weather_code=3.0
#     complete_time=21.05
# )
# No new drivers from update_driver_set with matching 'driver_area' ('625.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [20866.0]
# Driver pool has been randomized.
# Driver 20866.0 is initialized with location (32.6989452, 51.6745441)
# Driver 20866.0 can work at 2025-04-18 21:00.
# The distance calculated by geodesic is 1848.3762914319482
# Features input to the model for prediction:
# {'commission': [np.float64(18800.0)], 'driver_distance': [1848.3762914319482], 'hour': [21], 'weather_code': [3.0], 'work_time_minutes': [np.float64(211.63333336666668)]}
# Driver 20866.0 accept the order with probability of 0.48 and threshold 0.19426127578377295
# Add driver record: Driver 20866.0 has accepted 4883896 at 2025-04-18 21:44:22
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 20866.0
# Update current_order_index to 353
# Order(
#     order_id=4883897,
#     datetime=2025-04-18 22:01:12,
#     pickup_area=405.0,
#     dropoff_area=442.0,
#     pickup_lat=32.6476259,
#     pickup_lon=51.6958801,
#     dropoff_lat=32.663055,
#     dropoff_lon=51.6944417,
#     customer_price=45000.00,
#     commissionPercent=0.20,
#     driver_commission=9000.00,
#     platform_revenue=36000.00,
#     hour_of_day=22
#     weather_code=3.0
#     complete_time=15.466666666666669
# )
# Added new drivers to the pool based on matching 'driver_area' ('405.0'): [123.0]
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [123.0]
# Driver pool has been randomized.
# Driver 20061.0 is initialized with location (32.643735, 51.7024524)
# Driver 20061.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 752.621292288605
# Features input to the model for prediction:
# {'commission': [np.float64(9000.0)], 'driver_distance': [752.621292288605], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(33.18333333)]}
# Driver 20061.0 accept the order with probability of 0.6 and threshold 0.22251307176871093
# Add driver record: Driver 20061.0 has accepted 4883897 at 2025-04-18 22:01:12
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 20061.0
# Update current_order_index to 354
# Order(
#     order_id=4883898,
#     datetime=2025-04-18 22:24:04,
#     pickup_area=557.0,
#     dropoff_area=518.0,
#     pickup_lat=32.6931841,
#     pickup_lon=51.6718268,
#     dropoff_lat=32.6801101,
#     dropoff_lon=51.6553385,
#     customer_price=164000.00,
#     commissionPercent=0.20,
#     driver_commission=32800.00,
#     platform_revenue=131200.00,
#     hour_of_day=22
#     weather_code=3.0
#     complete_time=13.75
# )
# No new drivers from update_driver_set with matching 'driver_area' ('557.0') to add.
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [17442.0]
# Driver pool has been randomized.
# Driver 15730.0 is initialized with location (32.6996874, 51.6839152)
# Driver 15730.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 1343.534567715103
# Features input to the model for prediction:
# {'commission': [np.float64(32800.0)], 'driver_distance': [1343.534567715103], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 15730.0 did not accept the order with probability of 0.29 and threshold 0.3784971020075678
# Driver 6197.0 is initialized with location (32.7111385, 51.6752983)
# Driver 6197.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 2017.5595993947484
# Features input to the model for prediction:
# {'commission': [np.float64(32800.0)], 'driver_distance': [2017.5595993947484], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 6197.0 did not accept the order with probability of 0.33 and threshold 0.9275709498792374
# Driver 1461.0 is initialized with location (32.6892723, 51.6545362)
# Driver 1461.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 1678.4964622493899
# Features input to the model for prediction:
# {'commission': [np.float64(32800.0)], 'driver_distance': [1678.4964622493899], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 1461.0 did not accept the order with probability of 0.27 and threshold 0.547902190064565
# Driver 17442.0 is initialized with location (32.6863824, 51.7025512)
# Driver 17442.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 2978.398801430363
# Features input to the model for prediction:
# {'commission': [np.float64(32800.0)], 'driver_distance': [2978.398801430363], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(44.28333333333334)]}
# Driver 17442.0 accept the order with probability of 0.75 and threshold 0.4795785140489205
# Add driver record: Driver 17442.0 has accepted 4883898 at 2025-04-18 22:24:04
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 17442.0
# Update current_order_index to 355
# Order(
#     order_id=4883899,
#     datetime=2025-04-18 22:24:37,
#     pickup_area=284.0,
#     dropoff_area=285.0,
#     pickup_lat=32.622338,
#     pickup_lon=51.6567039,
#     dropoff_lat=32.6249891,
#     dropoff_lon=51.6671902,
#     customer_price=563000.00,
#     commissionPercent=0.20,
#     driver_commission=112600.00,
#     platform_revenue=450400.00,
#     hour_of_day=22
#     weather_code=3.0
#     complete_time=45.166666666666664
# )
# Added new drivers to the pool based on matching 'driver_area' ('284.0'): [12450.0]
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [15516.0, 12450.0]
# Driver pool has been randomized.
# Driver 15516.0 is initialized with location (32.6741469, 51.6865189)
# Driver 15516.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 6390.29635495669
# Features input to the model for prediction:
# {'commission': [np.float64(112600.0)], 'driver_distance': [6390.29635495669], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(46.2)]}
# Driver 15516.0 accept the order with probability of 0.64 and threshold 0.35740510572070094
# Add driver record: Driver 15516.0 has accepted 4883899 at 2025-04-18 22:24:37
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 15516.0
# Update current_order_index to 356
# Order(
#     order_id=4883900,
#     datetime=2025-04-18 22:25:02,
#     pickup_area=437.0,
#     dropoff_area=519.0,
#     pickup_lat=32.6550946,
#     pickup_lon=51.6430014,
#     dropoff_lat=32.6784767,
#     dropoff_lon=51.6716542,
#     customer_price=875000.00,
#     commissionPercent=0.20,
#     driver_commission=175000.00,
#     platform_revenue=700000.00,
#     hour_of_day=22
#     weather_code=3.0
#     complete_time=169.83333333333334
# )
# Added new drivers to the pool based on matching 'driver_area' ('437.0'): [20349.0, 17475.0]
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [20349.0, 17475.0]
# Driver pool has been randomized.
# Driver 13305.0 is initialized with location (32.6549606, 51.6422031)
# Driver 13305.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 76.35275408673589
# Features input to the model for prediction:
# {'commission': [np.float64(175000.0)], 'driver_distance': [76.35275408673589], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 13305.0 accept the order with probability of 0.66 and threshold 0.5453836104531349
# Add driver record: Driver 13305.0 has accepted 4883900 at 2025-04-18 22:25:02
# Order has been accepted, stop driver attampt
# Updated update_driver_set with driver_id: 13305.0
# Update current_order_index to 357
# Order(
#     order_id=4883901,
#     datetime=2025-04-18 22:31:12,
#     pickup_area=624.0,
#     dropoff_area=691.0,
#     pickup_lat=32.7097985,
#     pickup_lon=51.6607639,
#     dropoff_lat=32.7281567,
#     dropoff_lon=51.6587896,
#     customer_price=450000.00,
#     commissionPercent=0.20,
#     driver_commission=90000.00,
#     platform_revenue=360000.00,
#     hour_of_day=22
#     weather_code=3.0
#     complete_time=53.5
# )
# Added new drivers to the pool based on matching 'driver_area' ('624.0'): [21527.0]
# Using data in update_driver_set to update the following drivers in the pool (original and new area-matched): [21527.0]
# Driver pool has been randomized.
# Driver 2443.0 is initialized with location (32.7169147, 51.6779992)
# Driver 2443.0 can work at 2025-04-18 22:00.
# The distance calculated by geodesic is 1798.3002883355775
# Features input to the model for prediction:
# {'commission': [np.float64(90000.0)], 'driver_distance': [1798.3002883355775], 'hour': [22], 'weather_code': [3.0], 'work_time_minutes': [np.float64(0.0)]}
# Driver 2443.0 did not accept the order with probability of 0.24 and threshold 0.39016254602177924
# Driver 21527.0 is initialized with location (32.699235, 51.610865)
# Driver 21527.0 is not scheduled to work at 2025-04-18 22:00.
# Update current_order_index to 358
# Reach terminated condition: Finish simulating all the orders.

# %%
print(f"Number of Total Orders is {env.order_length}")
print(f"{len(env.driver_record.driver_record_table)} orders have been accepted.")
# Out:
# Number of Total Orders is 358
# 141 orders have been accepted.
